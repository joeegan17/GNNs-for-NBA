# %%
#Generic packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

# %%
import os

def get_opponent_id(game_id, team_id, df):
    opponent_data = df[(df['Game_ID'] == game_id) & (df['Team_ID'] != team_id)].iloc[0]
    return opponent_data['Team_ID']

def process_season_csv(file_path):
    df = pd.read_csv(file_path)
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    df.sort_values(by=['Team_ID', 'GAME_DATE'], inplace=True)

    #creating hte IS_HOME_TEAM feature
    df['IS_HOME_TEAM'] = df['MATCHUP'].str.contains('vs').astype(int)
    df['OPPONENT_ID'] = df.apply(lambda x: get_opponent_id(x['Game_ID'], x['Team_ID'], df), axis=1)

    # Initialize empty list to store results
    team_data_list = []

    for index, row in tqdm(df.iterrows(), total=df.shape[0]):
        team_data = get_team_features(row, df)
        team_data_list.append(team_data)
        
    team_data_df = pd.DataFrame(team_data_list)

    #add back in the  OPPONENT_ID column to the team_data_df
    team_data_df['OPPONENT_ID'] = df['OPPONENT_ID']

    return team_data_df


def get_team_features(current_game, df):
    team_id = current_game['Team_ID']
    game_id = current_game['Game_ID']
    team_data = df[(df['Team_ID'] == team_id) & (df['Game_ID'] < game_id)]
    features = {'Team_ID': team_id, 'Game_ID': game_id}

    #these are the features to average
    columns_to_avg = ['FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
    for col in columns_to_avg:
        features[f"AVG_{col}"] = team_data[col].mean()

    ####adding in the W, L, and W_PCT columns without modifications
    features['W'] = current_game['W']
    features['L'] = current_game['L']
    features['W_PCT'] = current_game['W_PCT']

    #compute W_PCT_PREV_10
    prev_10_games = team_data.tail(10)
    if len(prev_10_games) == 0:
        features['W_PCT_PREV_10'] = 0
    else:
        features['W_PCT_PREV_10'] = (prev_10_games['W'].max()- prev_10_games['W'].min())/ len(prev_10_games) 

    # Add IS_HOME_TEAM feature
    features['IS_HOME_TEAM'] = current_game['IS_HOME_TEAM']

    # Add HOME_TEAM_WINS label
    features['HOME_TEAM_WINS'] = int(current_game['WL'] == 'W' and current_game['IS_HOME_TEAM'])

    return features

# %%
def process_season_edge_csv(file_path):
    df = pd.read_csv(file_path)
    df['GAME_DATE'] = pd.to_datetime(df['GAME_DATE'])
    df.sort_values(by=['Team_ID', 'GAME_DATE'], inplace=True)

    #creating the IS home feature
    df['IS_HOME_TEAM'] = df['MATCHUP'].str.contains('vs').astype(int)
    df['OPPONENT_ID'] = df.apply(lambda x: get_opponent_id(x['Game_ID'], x['Team_ID'], df), axis=1)

    #for results
    edge_data_list = []

    for index, row in tqdm(df.iterrows(), total=df.shape[0]):
        if row['IS_HOME_TEAM']:
            team_data = create_edge_features(row, df)
            edge_data_list.append(team_data)
        
    team_data_df = pd.concat(edge_data_list, ignore_index=True)

    #and add in the opopnent id column
    team_data_df['OPPONENT_ID'] = df['OPPONENT_ID']

    return team_data_df

def create_edge_features(current_game, df):
    team_id = current_game['Team_ID']
    game_id = current_game['Game_ID']
    opponent_id = current_game['OPPONENT_ID']
    team_data = df[(df['Team_ID'] == team_id) & (df['Game_ID'] < game_id)]
    opponent_data = df[(df['Team_ID'] == opponent_id) & (df['Game_ID'] < game_id)]
    team_features = {'Team_ID': team_id, 'Game_ID': game_id}
    opponent_features = {'Team_ID': opponent_id, 'Game_ID': game_id}

    #values to average
    columns_to_avg = ['FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
    for col in columns_to_avg:
        team_features[f"AVG_{col}"] = team_data[col].mean()
        opponent_features[f"AVG_{col}"] = opponent_data[col].mean()


    ### put in the W, L, and W_PCT columns without modifications
    team_features['W'] = current_game['W']
    team_features['L'] = current_game['L']
    team_features['W_PCT'] = current_game['W_PCT']

    opp_game = df[(df['Team_ID'] == opponent_id) & (df['Game_ID'] == game_id)]
    opponent_features['W'] = opp_game['W']
    opponent_features['L'] = opp_game['L']
    opponent_features['W_PCT'] = opp_game['W_PCT']

    #trailing 10 games
    prev_10_games = team_data.tail(10)
    if len(prev_10_games) == 0:
        team_features['W_PCT_PREV_10'] = 0
    else:
        team_features['W_PCT_PREV_10'] = (prev_10_games['W'].max()- prev_10_games['W'].min())/ len(prev_10_games) 
    opp_prev_10_games = opponent_data.tail(10)
    if len(opp_prev_10_games) == 0:
        opponent_features['W_PCT_PREV_10'] = 0
    else:
        opponent_features['W_PCT_PREV_10'] = (opp_prev_10_games['W'].max()- opp_prev_10_games['W'].min())/ len(opp_prev_10_games)

    #Add IS_HOME_TEAM feature
    team_features['IS_HOME_TEAM'] = current_game['IS_HOME_TEAM']
    opponent_features['IS_HOME_TEAM'] = 0 if current_game['IS_HOME_TEAM'] else 1

    #Add HOME_TEAM_WINS label
    team_features['HOME_TEAM_WINS'] = int(current_game['WL'] == 'W' and current_game['IS_HOME_TEAM'])
    opponent_features['HOME_TEAM_WINS'] = int(current_game['WL'] == 'W' and not current_game['IS_HOME_TEAM'])

    edge_features_list = []

    #Calculate differences in features
    for col in columns_to_avg:
        edge_features_list.append(team_features[f"AVG_{col}"] - opponent_features[f"AVG_{col}"])

    ### Calculate differences in features for previous matchups
    
    prev_matchups = df[(df['Team_ID'] == team_id) & (df['OPPONENT_ID'] == opponent_id) & (df['Game_ID'] < game_id)]
    opp_prev_matchups = df[(df['Team_ID'] == opponent_id) & (df['OPPONENT_ID'] == team_id) & (df['Game_ID'] < game_id)]

    prev_matchup_features = {}
    for col in columns_to_avg:
        team_avg = prev_matchups[col].mean()
        opp_avg = opp_prev_matchups[col].mean()
        if not pd.isna(team_avg) and not pd.isna(opp_avg):
            prev_matchup_features[f"PREV_MATCHUP_DIFF_{col}"] = team_avg - opp_avg
        else:
            prev_matchup_features[f"PREV_MATCHUP_DIFF_{col}"] = 0

     # Combine edge features into a single dictionary
    edge_features = {}
    edge_features.update(team_features)
    edge_features.update(opponent_features)
    edge_features.update(prev_matchup_features)

    # Convert edge_features to a DataFrame with a single row
    edge_features_df = pd.DataFrame(edge_features, index=[0])

    return edge_features_df

# %%
csv_folder = "C:\\Users\\Joe\\Desktop\\Data Science Masters\\Tufts Spring 2023\\CS 150\\Final Project\\Input Data\\team"


#Process all CSV files and store results in a list
team_data_all = []

for file_name in os.listdir(csv_folder):
    if file_name.startswith("team_season_stats_") and file_name.endswith(".csv"):
        file_path = os.path.join(csv_folder, file_name)
        season_data = process_season_csv(file_path)
        team_data_all.append(season_data)

#combine all season data into one DataFrame
team_data_df = pd.concat(team_data_all)
team_data_df.to_csv("aggr_team_data.csv", index=False)
# Out:
# 100%|██████████| 2460/2460 [00:05<00:00, 447.74it/s]
# 100%|██████████| 2460/2460 [00:05<00:00, 456.81it/s]
# 100%|██████████| 2460/2460 [00:05<00:00, 459.55it/s]
# 100%|██████████| 2460/2460 [00:05<00:00, 451.26it/s]
# 100%|██████████| 2460/2460 [00:05<00:00, 452.55it/s]
# 100%|██████████| 2460/2460 [00:05<00:00, 467.50it/s]
# 100%|██████████| 2160/2160 [00:04<00:00, 461.45it/s]

# %%
csv_folder = "C:\\Users\\Joe\\Desktop\\Data Science Masters\\Tufts Spring 2023\\CS 150\\Final Project\\Input Data\\team"
#Creating edge features
edge_data_all = []


for file_name in os.listdir(csv_folder):
    if file_name.startswith("team_season_stats_") and file_name.endswith(".csv"):
        file_path = os.path.join(csv_folder, file_name)
        season_data = process_season_edge_csv(file_path)
        edge_data_all.append(season_data)

edge_features_df = pd.concat(edge_data_all)
edge_features_df.to_csv("edge_features.csv", index=False)
# Out:
# 100%|██████████| 2460/2460 [00:13<00:00, 185.82it/s]
# 100%|██████████| 2460/2460 [00:13<00:00, 185.29it/s]
# 100%|██████████| 2460/2460 [00:12<00:00, 189.69it/s]
# 100%|██████████| 2460/2460 [00:14<00:00, 175.02it/s]
# 100%|██████████| 2460/2460 [00:22<00:00, 108.07it/s]
# 100%|██████████| 2460/2460 [00:16<00:00, 147.16it/s]
# 100%|██████████| 2160/2160 [00:12<00:00, 167.65it/s]

# %%
len(edge_features_df)
# Out:
# 8460

# %%
test_list = set(team_data_df['Game_ID'].to_list())
print(len(test_list))
# Out:
# 8460

# %%
8460/(82*.5*30)
# Out:
# 6.878048780487805

# %%
edge_features_df.head(8)

# %%
############ PLAYER DATA ############

# %%
def process_player_data_csv(file_path):
    df = pd.read_csv(file_path)
    df.sort_values(by=['PLAYER_ID', 'GAME_ID'], inplace=True)
    df['MIN_x'] = df['MIN_x'].apply(lambda x: int(x.split('.')[0].split(':')[0]) + int(x.split(':')[1])/60 if pd.notnull(x) and isinstance(x, str) and ':' in x else x)



    #Initialize empty list to store results
    player_data_list = []

    for index, row in tqdm(df.iterrows(), desc="Processing rows", total=df.shape[0]):
        player_data = get_player_features(row, df)
        player_data_list.append(player_data)

    return pd.DataFrame(player_data_list)

def get_player_features(current_game, df):
    player_id = current_game['PLAYER_ID']
    game_id = current_game['GAME_ID']
    team_id = current_game['TEAM_ID']
    player_data = df[(df['PLAYER_ID'] == player_id) & (df['GAME_ID'] < game_id)]
    features = {'PLAYER_ID': player_id, 'Game_ID': game_id, 'Team_ID' : team_id}

    #Compute averages for relevant columns
    columns_to_avg = ['MIN_x', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS', 'PLUS_MINUS', 'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING', 'NET_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT', 'E_USG_PCT', 'E_PACE', 'PACE', 'PACE_PER40', 'POSS', 'PIE']
    for col in columns_to_avg:
        features[f"AVG_{col}"] = player_data[col].mean()

    #Add START_POSITION and DID_NOT_PLAY features
    features['START_POSITION'] = current_game['START_POSITION_x']
    features['DID_NOT_PLAY'] = 1 if pd.notnull(current_game['COMMENT_x']) else 0

    return features

# %%
import pandas as pd
import os as os
from tqdm import tqdm

csv_folder = "C:\\Users\\Joe\\Desktop\\Data Science Masters\\Tufts Spring 2023\\CS 150\\Final Project\\Input Data\\player"


player_data_all = []

#Process player data CSV file and store results in a list using our function
for file_name in os.listdir(csv_folder):
    if file_name.startswith("player_game_stats_") and file_name.endswith(".csv"):
        file_path = os.path.join(csv_folder, file_name)
        player_data_df = process_player_data_csv(file_path)
        player_data_all.append(player_data_df)

player_data_df_all = pd.concat(player_data_all)

player_data_df_all.to_csv("aggr_player_data.csv", index=False)
# Out:
# Processing rows: 100%|██████████| 33681/33681 [02:39<00:00, 211.66it/s]
# Processing rows: 100%|██████████| 37572/37572 [02:38<00:00, 236.49it/s]
# Processing rows: 100%|██████████| 37333/37333 [02:23<00:00, 260.15it/s]
# Processing rows: 100%|██████████| 37128/37128 [02:23<00:00, 259.28it/s]
# Processing rows: 100%|██████████| 35987/35987 [02:17<00:00, 260.82it/s]
# Processing rows: 100%|██████████| 35774/35774 [02:16<00:00, 261.24it/s]
# Processing rows: 100%|██████████| 33356/33356 [02:25<00:00, 229.87it/s]

# %%
player_data_df_all.head()
# Out:
#    PLAYER_ID   Game_ID     Team_ID  AVG_MIN_x   AVG_FGM  AVG_FGA  AVG_FG_PCT  \
# 0        708  21300004  1610612751        NaN       NaN      NaN         NaN
# 1        708  21300028  1610612751  26.283333  4.000000     8.00    0.500000
# 2        708  21300043  1610612751  26.041667  3.500000     9.50    0.386500
# 3        708  21300052  1610612751  24.833333  3.333333    10.00    0.348667
# 4        708  21300077  1610612751  22.025000  3.000000     8.75    0.361500
#
#    AVG_FG3M  AVG_FG3A  AVG_FG3_PCT  ...  AVG_TS_PCT  AVG_USG_PCT  \
# 0       NaN       NaN          NaN  ...         NaN          NaN
# 1       0.0  0.000000          0.0  ...      0.5000     0.179000
# 2       0.0  0.000000          0.0  ...      0.3865     0.210000
# 3       0.0  0.333333          0.0  ...      0.3700     0.232333
# 4       0.0  0.250000          0.0  ...      0.3775     0.232000
#
#    AVG_E_USG_PCT  AVG_E_PACE   AVG_PACE  AVG_PACE_PER40   AVG_POSS  AVG_PIE  \
# 0            NaN         NaN        NaN             NaN        NaN      NaN
# 1        0.17700   97.320000  94.980000       79.150000  52.000000    0.118
# 2        0.21300   97.815000  98.655000       82.210000  54.000000    0.068
# 3        0.23500   98.743333  99.316667       82.763333  51.333333    0.059
# 4        0.23525   96.435000  96.987500       80.822500  44.750000    0.076
#
#    START_POSITION  DID_NOT_PLAY
# 0               F             0
# 1               F             0
# 2               F             0
# 3               F             0
# 4               F             0
#
# [5 rows x 47 columns]

# %%
unique_player_ids_player_data = set(player_data_df_all['PLAYER_ID'].unique())

# %%
from nba_api.stats.endpoints import commonplayerinfo
import time



player_ids = unique_player_ids_player_data

#Empty DataFrame to store player information
player_info_df = pd.DataFrame(columns=['PLAYER_ID', 'HEIGHT', 'WEIGHT', 'BIRTHDATE'])

#Fetch player information
for player_id in tqdm(player_ids, desc="Fetching player info", total=len(player_ids)):
    player_info = commonplayerinfo.CommonPlayerInfo(player_id=player_id)
    player_info_data = player_info.get_data_frames()[0].iloc[0]
    time.sleep(0.6) ## need this for the API

    player_data = {
        'PLAYER_ID': player_id,
        'HEIGHT': player_info_data['HEIGHT'],
        'WEIGHT': player_info_data['WEIGHT'],
        'BIRTHDATE': player_info_data['BIRTHDATE']
    }
    
    player_info_df = player_info_df.append(player_data, ignore_index=True)

#Print the DataFrame
print(len(player_info_df))
print(len(unique_player_ids_player_data))
# Out:
# Fetching player info:   0%|          | 0/1710 [00:00<?, ?it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 1/1710 [00:00<27:08,  1.05it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 2/1710 [00:01<24:57,  1.14it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 3/1710 [00:02<25:40,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 4/1710 [00:03<28:33,  1.00s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 5/1710 [00:04<26:46,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 6/1710 [00:05<25:18,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 7/1710 [00:06<26:43,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   0%|          | 8/1710 [00:07<27:06,  1.05it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 9/1710 [00:08<26:06,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 10/1710 [00:09<26:07,  1.08it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 11/1710 [00:10<24:23,  1.16it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 12/1710 [00:10<24:00,  1.18it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 13/1710 [00:11<24:09,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 14/1710 [00:12<23:01,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 15/1710 [00:14<29:53,  1.06s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 16/1710 [00:14<27:52,  1.01it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 17/1710 [00:15<26:07,  1.08it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 18/1710 [00:16<25:28,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 19/1710 [00:17<25:46,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 20/1710 [00:18<24:10,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|          | 21/1710 [00:19<24:00,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|▏         | 22/1710 [00:19<23:39,  1.19it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|▏         | 23/1710 [00:20<22:54,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|▏         | 24/1710 [00:21<23:01,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   1%|▏         | 25/1710 [00:22<23:03,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 26/1710 [00:23<25:52,  1.08it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 27/1710 [00:24<24:36,  1.14it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 28/1710 [00:25<27:03,  1.04it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 29/1710 [00:26<26:21,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 30/1710 [00:27<25:28,  1.10it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 31/1710 [00:27<25:41,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 32/1710 [00:28<24:53,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 33/1710 [00:29<26:52,  1.04it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 34/1710 [00:31<29:59,  1.07s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 35/1710 [00:32<29:18,  1.05s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 36/1710 [00:33<27:21,  1.02it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 37/1710 [00:34<28:48,  1.03s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 38/1710 [00:34<26:16,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 39/1710 [00:35<24:24,  1.14it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 40/1710 [00:36<24:46,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 41/1710 [00:37<26:20,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   2%|▏         | 42/1710 [00:38<25:25,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 43/1710 [00:39<24:43,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 44/1710 [00:40<24:56,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 45/1710 [00:41<23:31,  1.18it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 46/1710 [00:41<22:43,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 47/1710 [00:42<22:49,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 48/1710 [00:43<22:48,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 49/1710 [00:44<22:25,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 50/1710 [00:45<22:15,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 51/1710 [00:45<22:26,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 52/1710 [00:46<21:53,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 53/1710 [00:47<22:17,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 54/1710 [00:48<21:24,  1.29it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 55/1710 [00:48<20:52,  1.32it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 56/1710 [00:49<22:40,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 57/1710 [00:50<22:44,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 58/1710 [00:51<22:49,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   3%|▎         | 59/1710 [00:52<24:42,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▎         | 60/1710 [00:53<24:46,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▎         | 61/1710 [00:54<23:30,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▎         | 62/1710 [00:54<22:29,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▎         | 63/1710 [00:55<21:59,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▎         | 64/1710 [00:56<21:04,  1.30it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 65/1710 [00:57<21:05,  1.30it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 66/1710 [00:57<21:20,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 67/1710 [00:58<20:52,  1.31it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 68/1710 [01:01<34:07,  1.25s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 69/1710 [01:02<32:33,  1.19s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 70/1710 [01:02<28:55,  1.06s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 71/1710 [01:03<29:08,  1.07s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 72/1710 [01:04<26:09,  1.04it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 73/1710 [01:05<24:21,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 74/1710 [01:06<26:12,  1.04it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 75/1710 [01:07<24:23,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   4%|▍         | 76/1710 [01:07<22:43,  1.20it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 77/1710 [01:08<22:54,  1.19it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 78/1710 [01:09<25:23,  1.07it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 79/1710 [01:10<25:37,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 80/1710 [01:11<24:29,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 81/1710 [01:12<23:06,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 82/1710 [01:13<22:37,  1.20it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 83/1710 [01:14<23:04,  1.18it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 84/1710 [01:14<22:58,  1.18it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▍         | 85/1710 [01:15<22:04,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 86/1710 [01:16<21:35,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 87/1710 [01:17<21:13,  1.27it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 88/1710 [01:18<21:47,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 89/1710 [01:18<21:34,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 90/1710 [01:19<20:47,  1.30it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 91/1710 [01:20<22:08,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 92/1710 [01:21<22:15,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 93/1710 [01:22<21:35,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   5%|▌         | 94/1710 [01:22<21:39,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 95/1710 [01:23<21:15,  1.27it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 96/1710 [01:24<20:53,  1.29it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 97/1710 [01:25<23:59,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 98/1710 [01:26<23:06,  1.16it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 99/1710 [01:27<26:19,  1.02it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 100/1710 [01:28<25:03,  1.07it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 101/1710 [01:29<24:14,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 102/1710 [01:30<22:58,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 103/1710 [01:30<21:53,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 104/1710 [01:31<22:00,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 105/1710 [01:32<21:53,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▌         | 106/1710 [01:33<21:39,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▋         | 107/1710 [01:33<21:35,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▋         | 108/1710 [01:34<21:51,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▋         | 109/1710 [01:35<21:10,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▋         | 110/1710 [01:36<21:24,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   6%|▋         | 111/1710 [01:37<23:20,  1.14it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 112/1710 [01:38<21:51,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 113/1710 [01:38<21:15,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 114/1710 [01:39<20:42,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 115/1710 [01:41<27:03,  1.02s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 116/1710 [01:42<27:23,  1.03s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 117/1710 [01:43<25:51,  1.03it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 118/1710 [01:44<26:08,  1.02it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 119/1710 [01:44<24:19,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 120/1710 [01:45<26:03,  1.02it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 121/1710 [01:46<24:32,  1.08it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 122/1710 [01:47<23:21,  1.13it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 123/1710 [01:48<22:44,  1.16it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 124/1710 [01:49<24:16,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 125/1710 [01:50<24:32,  1.08it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 126/1710 [01:51<25:00,  1.06it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 127/1710 [01:52<24:33,  1.07it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   7%|▋         | 128/1710 [01:53<23:55,  1.10it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 129/1710 [01:53<22:40,  1.16it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 130/1710 [01:54<23:47,  1.11it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 131/1710 [01:55<24:39,  1.07it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 132/1710 [01:57<26:14,  1.00it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 133/1710 [01:58<26:57,  1.03s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 134/1710 [01:59<27:59,  1.07s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 135/1710 [02:00<28:32,  1.09s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 136/1710 [02:02<35:11,  1.34s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 137/1710 [02:03<31:32,  1.20s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 138/1710 [02:03<28:00,  1.07s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:   8%|▊         | 139/1710 [02:05<28:57,  1.11s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# ...
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  97%|█████████▋| 1664/1710 [25:10<00:36,  1.27it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  97%|█████████▋| 1665/1710 [25:10<00:35,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  97%|█████████▋| 1666/1710 [25:11<00:36,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  97%|█████████▋| 1667/1710 [25:12<00:34,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1668/1710 [25:13<00:33,  1.27it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1669/1710 [25:13<00:31,  1.30it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1670/1710 [25:14<00:32,  1.23it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1671/1710 [25:15<00:32,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1672/1710 [25:16<00:32,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1673/1710 [25:17<00:30,  1.22it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1674/1710 [25:18<00:28,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1675/1710 [25:18<00:27,  1.29it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1676/1710 [25:19<00:27,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1677/1710 [25:20<00:26,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1678/1710 [25:21<00:25,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1679/1710 [25:22<00:24,  1.27it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1680/1710 [25:23<00:30,  1.00s/it]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1681/1710 [25:24<00:27,  1.04it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1682/1710 [25:25<00:25,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1683/1710 [25:25<00:22,  1.18it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  98%|█████████▊| 1684/1710 [25:26<00:22,  1.15it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▊| 1685/1710 [25:27<00:21,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▊| 1686/1710 [25:28<00:19,  1.20it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▊| 1687/1710 [25:29<00:18,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▊| 1688/1710 [25:29<00:17,  1.29it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1689/1710 [25:30<00:16,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1690/1710 [25:31<00:17,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1691/1710 [25:32<00:16,  1.17it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1692/1710 [25:33<00:14,  1.20it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1693/1710 [25:34<00:13,  1.25it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1694/1710 [25:34<00:12,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1695/1710 [25:35<00:11,  1.29it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1696/1710 [25:36<00:10,  1.28it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1697/1710 [25:37<00:10,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1698/1710 [25:38<00:09,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1699/1710 [25:39<00:10,  1.09it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1700/1710 [25:40<00:08,  1.12it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info:  99%|█████████▉| 1701/1710 [25:40<00:07,  1.19it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1702/1710 [25:41<00:06,  1.19it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1703/1710 [25:42<00:06,  1.07it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1704/1710 [25:43<00:05,  1.15it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1705/1710 [25:44<00:04,  1.15it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1706/1710 [25:45<00:03,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1707/1710 [25:45<00:02,  1.21it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1708/1710 [25:46<00:01,  1.26it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|█████████▉| 1709/1710 [25:47<00:00,  1.24it/s]C:\Users\Joe\AppData\Local\Temp\ipykernel_9260\3197184227.py:24: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   player_info_df = player_info_df.append(player_data, ignore_index=True)
# Fetching player info: 100%|██████████| 1710/1710 [25:48<00:00,  1.10it/s]
# 1710
# 1710

# %%
len(player_info_df[player_info_df['HEIGHT'].isnull() | player_info_df['HEIGHT'].eq("")])
#509
# Out:
# 509

# %%
#this data is incomplete so can't really use it....
import datetime as dt

def height_to_inches(height):
    try:
        feet, inches = height.split('-')
        return int(feet) * 12 + int(inches)
    except:
        pass
    

def birthdate_to_days(birthdate):
    return (pd.to_datetime(birthdate) - pd.Timestamp("1970-01-01")) // pd.Timedelta("1D")

#Convert height to inches
player_info_df['HEIGHT'] = player_info_df['HEIGHT'].apply(height_to_inches)

#Convert birthdate to an integer (days since 1970-01-01)
player_info_df['BIRTHDATE'] = player_info_df['BIRTHDATE'].apply(birthdate_to_days)

print(player_info_df.head())
# Out:
#   PLAYER_ID  HEIGHT WEIGHT  BIRTHDATE
# 0   1630208    84.0    245      10194
# 1   1630210    70.0    175      10653
# 2   1630211    75.0    190      11093
# 3   1630213     NaN             10239
# 4   1630214    79.0    245      10603

# %%
player_bday_df = player_info_df[['PLAYER_ID', 'BIRTHDATE']]

# %%
player_bday_df['BIRTHDATE'].eq('').sum()
#0
# Out:
# 0

# %%
player_data_all_df_with_bday = player_data_df_all.merge(player_bday_df, on='PLAYER_ID', how='left')

# %%
len(player_data_all_df_with_bday)
#250831
# Out:
# 250831

# %%
player_data_all_df_with_bday.head()
# Out:
#   PLAYER_ID   Game_ID     Team_ID  AVG_MIN_x   AVG_FGM  AVG_FGA  AVG_FG_PCT  \
# 0       708  21300004  1610612751        NaN       NaN      NaN         NaN
# 1       708  21300028  1610612751  26.283333  4.000000     8.00    0.500000
# 2       708  21300043  1610612751  26.041667  3.500000     9.50    0.386500
# 3       708  21300052  1610612751  24.833333  3.333333    10.00    0.348667
# 4       708  21300077  1610612751  22.025000  3.000000     8.75    0.361500
#
#    AVG_FG3M  AVG_FG3A  AVG_FG3_PCT  ...  AVG_USG_PCT  AVG_E_USG_PCT  \
# 0       NaN       NaN          NaN  ...          NaN            NaN
# 1       0.0  0.000000          0.0  ...     0.179000        0.17700
# 2       0.0  0.000000          0.0  ...     0.210000        0.21300
# 3       0.0  0.333333          0.0  ...     0.232333        0.23500
# 4       0.0  0.250000          0.0  ...     0.232000        0.23525
#
#    AVG_E_PACE   AVG_PACE  AVG_PACE_PER40   AVG_POSS  AVG_PIE  START_POSITION  \
# 0         NaN        NaN             NaN        NaN      NaN               F
# 1   97.320000  94.980000       79.150000  52.000000    0.118               F
# 2   97.815000  98.655000       82.210000  54.000000    0.068               F
# 3   98.743333  99.316667       82.763333  51.333333    0.059               F
# 4   96.435000  96.987500       80.822500  44.750000    0.076               F
#
#    DID_NOT_PLAY  BIRTHDATE
# 0             0       2330
# 1             0       2330
# 2             0       2330
# 3             0       2330
# 4             0       2330
#
# [5 rows x 48 columns]

# %%
player_data_all_df_with_bday.to_csv("aggr_player_data_full.csv", index=False)
